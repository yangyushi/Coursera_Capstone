# %% [markdown]
# # Coursera Capstone
#
#
# This notebook is created for the course [Applied Data Science Capstone](https://www.coursera.org/learn/applied-data-science-capstone/home/welcome) and it is about applying machine learning algorithms to analyse car accidents

# %%
import numpy as np
import pandas as pd

# %%
print("Hello Capstone Project Course")
# Out:
# Hello Capstone Project Course
